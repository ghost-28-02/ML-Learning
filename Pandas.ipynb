# %%
import pandas as pd

# %%
s = pd.Series([2, -1, 3, 5])
s
# Out:
# 0    2
# 1   -1
# 2    3
# 3    5
# dtype: int64

# %%
import numpy as np
np.exp(s)
# Out:
# 0      7.389056
# 1      0.367879
# 2     20.085537
# 3    148.413159
# dtype: float64

# %%
s + [1000, 2000, 3000, 4000]
# Out:
# 0    1002
# 1    1999
# 2    3003
# 3    4005
# dtype: int64

# %%
s + 1000
# Out:
# 0    1002
# 1     999
# 2    1003
# 3    1005
# dtype: int64

# %%
s < 0
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
s2 = pd.Series([68, 83, 112, 68], index=['alice', 'bob', 'charles', 'darwin'])
s2
# Out:
# alice       68
# bob         83
# charles    112
# darwin      68
# dtype: int64

# %%
s2['bob']
# Out:
# np.int64(83)

# %%
s2.loc['bob']
# Out:
# np.int64(83)

# %%
s2.iloc[1]
# Out:
# np.int64(83)

# %%
s2.iloc[1:3]
# Out:
# bob         83
# charles    112
# dtype: int64

# %%
surprise = pd.Series([1000, 1001, 1002, 1003])
surprise
# Out:
# 0    1000
# 1    1001
# 2    1002
# 3    1003
# dtype: int64

# %%
surprise_slice = surprise[2:]
surprise_slice
# Out:
# 2    1002
# 3    1003
# dtype: int64

# %%
try:
    surprise_slice[0]
except KeyError as e:
    print("Key error:", e)
# Out:
# Key error: 0

# %%
surprise_slice.iloc[0]
# Out:
# np.int64(1002)

# %%
weights = {"alice": 68, "bob": 83, "colin": 86, "darwin": 68}
s3 = pd.Series(weights)
s3
# Out:
# alice     68
# bob       83
# colin     86
# darwin    68
# dtype: int64

# %%
s4 = pd.Series(weights, index = ["colin", 'alice'])
s4
# Out:
# colin    86
# alice    68
# dtype: int64

# %%
print(s2.keys())
print(s3.keys())

s2 + s3
# Out:
# Index(['alice', 'bob', 'charles', 'darwin'], dtype='object')
# Index(['alice', 'bob', 'colin', 'darwin'], dtype='object')
# alice      136.0
# bob        166.0
# charles      NaN
# colin        NaN
# darwin     136.0
# dtype: float64

# %%
s5 = pd.Series([1000, 1000, 1000, 1000])
print("s2 =", s2.values)
print("s5 =", s5.values)

s2 + s5
# Out:
# s2 = [ 68  83 112  68]
# s5 = [1000 1000 1000 1000]
# alice     NaN
# bob       NaN
# charles   NaN
# darwin    NaN
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# dtype: float64

# %%
meaning = pd.Series(42, ['life', 'universe', 'everything'])
meaning
# Out:
# life          42
# universe      42
# everything    42
# dtype: int64

# %%
s6 = pd.Series([83, 68], index=['bob','alice'], name='weights')
s6
# Out:
# bob      83
# alice    68
# Name: weights, dtype: int64

# %%
import matplotlib.pyplot as plt
temperatures = [4.4, 5.1, 6.1, 6.2, 6.1, 6.1, 5.7, 5.2, 4.7, 4.1, 3.9, 3.5]
s7 = pd.Series(temperatures, name='Temperature')
s7.plot()
plt.show()

# %%
dates = pd.date_range('2026/1/20 5:30pm', periods=12, freq='h')
dates
# Out:
# DatetimeIndex(['2026-01-20 17:30:00', '2026-01-20 18:30:00',
#                '2026-01-20 19:30:00', '2026-01-20 20:30:00',
#                '2026-01-20 21:30:00', '2026-01-20 22:30:00',
#                '2026-01-20 23:30:00', '2026-01-21 00:30:00',
#                '2026-01-21 01:30:00', '2026-01-21 02:30:00',
#                '2026-01-21 03:30:00', '2026-01-21 04:30:00'],
#               dtype='datetime64[ns]', freq='h')

# %%
temp_series = pd.Series(temperatures, dates)
temp_series
# Out:
# 2026-01-20 17:30:00    4.4
# 2026-01-20 18:30:00    5.1
# 2026-01-20 19:30:00    6.1
# 2026-01-20 20:30:00    6.2
# 2026-01-20 21:30:00    6.1
# 2026-01-20 22:30:00    6.1
# 2026-01-20 23:30:00    5.7
# 2026-01-21 00:30:00    5.2
# 2026-01-21 01:30:00    4.7
# 2026-01-21 02:30:00    4.1
# 2026-01-21 03:30:00    3.9
# 2026-01-21 04:30:00    3.5
# Freq: h, dtype: float64

# %%
temp_series.plot(kind='bar')

plt.grid(True)
plt.show()

# %%
temp_series_freq_2h = temp_series.resample("2h")
temp_series_freq_2h

# %%
temp_series_freq_2h = temp_series_freq_2h.mean()

# %%
temp_series_freq_2h.plot(kind='bar')
plt.show()

# %%
temp_series_freq_2h = temp_series.resample("2h").min()
temp_series_freq_2h
# Out:
# 2026-01-20 16:00:00    4.4
# 2026-01-20 18:00:00    5.1
# 2026-01-20 20:00:00    6.1
# 2026-01-20 22:00:00    5.7
# 2026-01-21 00:00:00    4.7
# 2026-01-21 02:00:00    3.9
# 2026-01-21 04:00:00    3.5
# Freq: 2h, dtype: float64

# %%
temp_series_freq_2h = temp_series.resample("2h").apply("min")
temp_series_freq_2h
# Out:
# 2026-01-20 16:00:00    4.4
# 2026-01-20 18:00:00    5.1
# 2026-01-20 20:00:00    6.1
# 2026-01-20 22:00:00    5.7
# 2026-01-21 00:00:00    4.7
# 2026-01-21 02:00:00    3.9
# 2026-01-21 04:00:00    3.5
# Freq: 2h, dtype: float64

# %%
temp_series_freq_15min = temp_series.resample("15Min").mean()
temp_series_freq_15min.head(n=10)
# Out:
# 2026-01-20 17:30:00    4.4
# 2026-01-20 17:45:00    NaN
# 2026-01-20 18:00:00    NaN
# 2026-01-20 18:15:00    NaN
# 2026-01-20 18:30:00    5.1
# 2026-01-20 18:45:00    NaN
# 2026-01-20 19:00:00    NaN
# 2026-01-20 19:15:00    NaN
# 2026-01-20 19:30:00    6.1
# 2026-01-20 19:45:00    NaN
# Freq: 15min, dtype: float64

# %%
temp_series_freq_15min = temp_series.resample("15Min").interpolate(method='cubic')
temp_series_freq_15min.head(n=10)
# Out:
# 2026-01-20 17:30:00    4.400000
# 2026-01-20 17:45:00    4.452911
# 2026-01-20 18:00:00    4.605113
# 2026-01-20 18:15:00    4.829758
# 2026-01-20 18:30:00    5.100000
# 2026-01-20 18:45:00    5.388992
# 2026-01-20 19:00:00    5.669887
# 2026-01-20 19:15:00    5.915839
# 2026-01-20 19:30:00    6.100000
# 2026-01-20 19:45:00    6.203621
# Freq: 15min, dtype: float64

# %%
temp_series.plot(label="Period: 1 hour")
temp_series_freq_15min.plot(label="Period: 15 minutes")
plt.legend()
plt.show()

# %%
temp_series_ny = temp_series.tz_localize("America/New_York")
temp_series
# Out:
# 2026-01-20 17:30:00    4.4
# 2026-01-20 18:30:00    5.1
# 2026-01-20 19:30:00    6.1
# 2026-01-20 20:30:00    6.2
# 2026-01-20 21:30:00    6.1
# 2026-01-20 22:30:00    6.1
# 2026-01-20 23:30:00    5.7
# 2026-01-21 00:30:00    5.2
# 2026-01-21 01:30:00    4.7
# 2026-01-21 02:30:00    4.1
# 2026-01-21 03:30:00    3.9
# 2026-01-21 04:30:00    3.5
# Freq: h, dtype: float64

# %%
temp_series_paris = temp_series_ny.tz_convert("Europe/Paris")
temp_series_paris
# Out:
# 2026-01-20 23:30:00+01:00    4.4
# 2026-01-21 00:30:00+01:00    5.1
# 2026-01-21 01:30:00+01:00    6.1
# 2026-01-21 02:30:00+01:00    6.2
# 2026-01-21 03:30:00+01:00    6.1
# 2026-01-21 04:30:00+01:00    6.1
# 2026-01-21 05:30:00+01:00    5.7
# 2026-01-21 06:30:00+01:00    5.2
# 2026-01-21 07:30:00+01:00    4.7
# 2026-01-21 08:30:00+01:00    4.1
# 2026-01-21 09:30:00+01:00    3.9
# 2026-01-21 10:30:00+01:00    3.5
# dtype: float64

# %%
temp_series_paris_naive = temp_series_paris.tz_localize(None)
temp_series_paris_naive
# Out:
# 2026-01-20 23:30:00    4.4
# 2026-01-21 00:30:00    5.1
# 2026-01-21 01:30:00    6.1
# 2026-01-21 02:30:00    6.2
# 2026-01-21 03:30:00    6.1
# 2026-01-21 04:30:00    6.1
# 2026-01-21 05:30:00    5.7
# 2026-01-21 06:30:00    5.2
# 2026-01-21 07:30:00    4.7
# 2026-01-21 08:30:00    4.1
# 2026-01-21 09:30:00    3.9
# 2026-01-21 10:30:00    3.5
# dtype: float64

# %%
try:
    temp_series_paris_naive.tz_localize("Europe/Paris")
except Exception as e:
    print(type(e))
    print(e)

# %%
temp_series_paris_naive.tz_localize("Europe/Paris", ambiguous="infer")
# Out:
# 2026-01-20 23:30:00+01:00    4.4
# 2026-01-21 00:30:00+01:00    5.1
# 2026-01-21 01:30:00+01:00    6.1
# 2026-01-21 02:30:00+01:00    6.2
# 2026-01-21 03:30:00+01:00    6.1
# 2026-01-21 04:30:00+01:00    6.1
# 2026-01-21 05:30:00+01:00    5.7
# 2026-01-21 06:30:00+01:00    5.2
# 2026-01-21 07:30:00+01:00    4.7
# 2026-01-21 08:30:00+01:00    4.1
# 2026-01-21 09:30:00+01:00    3.9
# 2026-01-21 10:30:00+01:00    3.5
# dtype: float64

# %%
quarters = pd.period_range('2016Q1', periods=8, freq='Q')
quarters
# Out:
# PeriodIndex(['2016Q1', '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2',
#              '2017Q3', '2017Q4'],
#             dtype='period[Q-DEC]')

# %%
quarters + 3
# Out:
# PeriodIndex(['2016Q4', '2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1',
#              '2018Q2', '2018Q3'],
#             dtype='period[Q-DEC]')

# %%
quarters.asfreq("M")
# Out:
# PeriodIndex(['2016-03', '2016-06', '2016-09', '2016-12', '2017-03', '2017-06',
#              '2017-09', '2017-12'],
#             dtype='period[M]')

# %%
quarters.asfreq("M", how="start")
# Out:
# PeriodIndex(['2016-01', '2016-04', '2016-07', '2016-10', '2017-01', '2017-04',
#              '2017-07', '2017-10'],
#             dtype='period[M]')

# %%
quarters.asfreq("Y")
# Out:
# PeriodIndex(['2016', '2016', '2016', '2016', '2017', '2017', '2017', '2017'], dtype='period[Y-DEC]')

# %%
quarterly_revenue = pd.Series([300, 320, 290, 390, 320, 360, 310, 410], index=quarters)
quarterly_revenue
# Out:
# 2016Q1    300
# 2016Q2    320
# 2016Q3    290
# 2016Q4    390
# 2017Q1    320
# 2017Q2    360
# 2017Q3    310
# 2017Q4    410
# Freq: Q-DEC, dtype: int64

# %%
quarterly_revenue.plot(kind='line')
plt.show()

# %%
last_hours = quarterly_revenue.to_timestamp(how='end', freq='h')
last_hours
# Out:
# 2016-03-31 23:59:59.999999999    300
# 2016-06-30 23:59:59.999999999    320
# 2016-09-30 23:59:59.999999999    290
# 2016-12-31 23:59:59.999999999    390
# 2017-03-31 23:59:59.999999999    320
# 2017-06-30 23:59:59.999999999    360
# 2017-09-30 23:59:59.999999999    310
# 2017-12-31 23:59:59.999999999    410
# dtype: int64

# %%
last_hours.to_period()
# Out:
# 2016Q1    300
# 2016Q2    320
# 2016Q3    290
# 2016Q4    390
# 2017Q1    320
# 2017Q2    360
# 2017Q3    310
# 2017Q4    410
# Freq: Q-DEC, dtype: int64

# %%
people_dict = {
    "weight": pd.Series([68, 83, 112], index=['alice', 'bob', 'charles']),
    'birthyear': pd.Series([1984, 1985, 1992], index=['bob', 'alice', 'charles'], name='year'),
    'children': pd.Series([0,3], index=['charles', 'bob']),
    'hobby': pd.Series(['Biking', 'Dancing'], index=['alice','bob'])
}

people = pd.DataFrame(people_dict)
people
# Out:
#          weight  birthyear  children    hobby
# alice        68       1985       NaN   Biking
# bob          83       1984       3.0  Dancing
# charles     112       1992       0.0      NaN

# %%
people['birthyear']
# Out:
# alice      1985
# bob        1984
# charles    1992
# Name: birthyear, dtype: int64

# %%
people[['birthyear','hobby']]
# Out:
#          birthyear    hobby
# alice         1985   Biking
# bob           1984  Dancing
# charles       1992      NaN

# %%
d2 = pd.DataFrame(
    people_dict,
    columns=['birthyear','weight','height'],
    index=['bob','alice', 'eugene']
)

d2
# Out:
#         birthyear  weight height
# bob        1984.0    83.0    NaN
# alice      1985.0    68.0    NaN
# eugene        NaN     NaN    NaN

# %%
values = [
    [1985, np.nan, 'Biking', 68],
    [1984, 3, "Dancing", 83],
    [1992, 0, np.nan, 112]
]

d3 = pd.DataFrame(
    values,
    columns=["birthyear", "children", "hobby", "weight"],
    index=["alice", "bob", "charles"]
)
d3
# Out:
#          birthyear  children    hobby  weight
# alice         1985       NaN   Biking      68
# bob           1984       3.0  Dancing      83
# charles       1992       0.0      NaN     112

# %%
masked_array = np.ma.asarray(values, dtype=object)
masked_array[(0,2),(1,2)] = np.ma.masked
d3 = pd.DataFrame(
    masked_array,
    columns=["birthyear", "children", "hobby", "weight"],
    index=["alice", "bob", "charles"]
)
d3
# Out:
#         birthyear children    hobby weight
# alice        1985      NaN   Biking     68
# bob          1984        3  Dancing     83
# charles      1992        0      NaN    112

# %%
d4 = pd.DataFrame(
    d3, 
    columns=["hobby", "children"],
    index=["alice", "bob"]
)
d4
# Out:
#          hobby children
# alice   Biking      NaN
# bob    Dancing        3

# %%
people = pd.DataFrame({
    "birthyear": {"alice": 1985, "bob": 1984, "charles": 1992},
    "hobby": {"alice": "Biking", "bob": "Dancing"},
    "weight": {"alice": 68, "bob": 83, "charles": 112},
    "children": {"bob": 3, "charles": 0}
})
people
# Out:
#          birthyear    hobby  weight  children
# alice         1985   Biking      68       NaN
# bob           1984  Dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
d5 = pd.DataFrame(
    {
        ("public", "birthyear"):
            {("Paris","alice") : 1985, ("Paris", "bob") : 1984, ("London","charles"): 1992},
        ("public", "hobby"):
            {("Paris","alice"): "Biking", ("Paris","bob"): "Dancing"},
        ("private", "weight"):
        {("Paris","alice"): 68, ("Paris","bob"): 83, ("London","charles"): 112},
        ("private", "children"):
            {("Paris", "alice"): np.nan, ("Paris","bob"): 3, ("London","charles"): 0}
  
    }
)

d5
# Out:
#                   public          private
#                birthyear    hobby  weight children
# Paris  alice        1985   Biking      68      NaN
#        bob          1984  Dancing      83      3.0
# London charles      1992      NaN     112      0.0

# %%
d5['public']
# Out:
#                 birthyear    hobby
# Paris  alice         1985   Biking
#        bob           1984  Dancing
# London charles       1992      NaN

# %%
d5["public","hobby"]
# Out:
# Paris   alice       Biking
#         bob        Dancing
# London  charles        NaN
# Name: (public, hobby), dtype: object

# %%
d5
# Out:
#                   public          private
#                birthyear    hobby  weight children
# Paris  alice        1985   Biking      68      NaN
#        bob          1984  Dancing      83      3.0
# London charles      1992      NaN     112      0.0

# %%
d5.columns = d5.columns.droplevel(level=0)
d5
# Out:
#                 birthyear    hobby  weight  children
# Paris  alice         1985   Biking      68       NaN
#        bob           1984  Dancing      83       3.0
# London charles       1992      NaN     112       0.0

# %%
d6 = d5.T
d6
# Out:
#             Paris           London
#             alice      bob charles
# birthyear    1985     1984    1992
# hobby      Biking  Dancing     NaN
# weight         68       83     112
# children      NaN      3.0     0.0

# %%
d7 = d6.stack()
d7
# Out:
# /tmp/ipython-input-3230766657.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   d7 = d6.stack()
#                      Paris London
# birthyear alice       1985    NaN
#           bob         1984    NaN
#           charles      NaN   1992
# hobby     alice     Biking    NaN
#           bob      Dancing    NaN
# weight    alice         68    NaN
#           bob           83    NaN
#           charles      NaN    112
# children  bob          3.0    NaN
#           charles      NaN    0.0

# %%
d8 = d7.unstack()
d8
# Out:
#             Paris                  London
#             alice      bob charles  alice  bob charles
# birthyear    1985     1984     NaN    NaN  NaN    1992
# children      NaN      3.0     NaN    NaN  NaN     0.0
# hobby      Biking  Dancing     NaN    NaN  NaN     NaN
# weight         68       83     NaN    NaN  NaN     112

# %%
d9 = d8.unstack()
d9
# Out:
# Paris   alice    birthyear       1985
#                  children         NaN
#                  hobby         Biking
#                  weight            68
#         bob      birthyear       1984
#                  children         3.0
#                  hobby        Dancing
#                  weight            83
#         charles  birthyear        NaN
#                  children         NaN
#                  hobby            NaN
#                  weight           NaN
# London  alice    birthyear        NaN
#                  children         NaN
#                  hobby            NaN
#                  weight           NaN
#         bob      birthyear        NaN
#                  children         NaN
#                  hobby            NaN
#                  weight           NaN
#         charles  birthyear       1992
#                  children         0.0
#                  hobby            NaN
#                  weight           112
# dtype: object

# %%
d10 = d9.unstack(level=(0,1))
d10
# Out:
#             Paris                  London
#             alice      bob charles  alice  bob charles
# birthyear    1985     1984     NaN    NaN  NaN    1992
# children      NaN      3.0     NaN    NaN  NaN     0.0
# hobby      Biking  Dancing     NaN    NaN  NaN     NaN
# weight         68       83     NaN    NaN  NaN     112

# %%
people
# Out:
#          birthyear    hobby  weight  children
# alice         1985   Biking      68       NaN
# bob           1984  Dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
people.loc["charles"]
# Out:
# birthyear    1992
# hobby         NaN
# weight        112
# children      0.0
# Name: charles, dtype: object

# %%
people.iloc[2]
# Out:
# birthyear    1992
# hobby         NaN
# weight        112
# children      0.0
# Name: charles, dtype: object

# %%
people.iloc[1:3]
# Out:
#          birthyear    hobby  weight  children
# bob           1984  Dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
people[np.array([True, False, True])]
# Out:
#          birthyear   hobby  weight  children
# alice         1985  Biking      68       NaN
# charles       1992     NaN     112       0.0

# %%
people[people["birthyear"] < 1990]
# Out:
#        birthyear    hobby  weight  children
# alice       1985   Biking      68       NaN
# bob         1984  Dancing      83       3.0

# %%
people
# Out:
#          birthyear    hobby  weight  children
# alice         1985   Biking      68       NaN
# bob           1984  Dancing      83       3.0
# charles       1992      NaN     112       0.0

# %%
people["age"] = 2026 - people["birthyear"]
people["over 30"] = people["age"] > 40
birthyears = people.pop("birthyear")
del people["children"]

people
# Out:
#            hobby  weight  age  over 30
# alice     Biking      68   41     True
# bob      Dancing      83   42     True
# charles      NaN     112   34    False

# %%
birthyears
# Out:
# alice      1985
# bob        1984
# charles    1992
# Name: birthyear, dtype: int64

# %%
people["pets"] = pd.Series({"bob": 0, "charles":5, "eugene":1})
people
# Out:
#            hobby  weight  age  over 30  pets
# alice     Biking      68   41     True   NaN
# bob      Dancing      83   42     True   0.0
# charles      NaN     112   34    False   5.0

# %%
people.insert(1, "height", [172, 181, 185])
people
# Out:
#            hobby  height  weight  age  over 30  pets
# alice     Biking     172      68   41     True   NaN
# bob      Dancing     181      83   42     True   0.0
# charles      NaN     185     112   34    False   5.0

# %%
people = people.assign(
    body_mass_index = people["weight"] / (people["height"]/100) ** 2,
    has_pets = people["pets"] > 0
)

# %%
people
# Out:
#            hobby  height  weight  age  over 30  pets  body_mass_index  \
# alice     Biking     172      68   41     True   NaN        22.985398
# bob      Dancing     181      83   42     True   0.0        25.335002
# charles      NaN     185     112   34    False   5.0        32.724617
#
#          has_pets
# alice       False
# bob         False
# charles      True

# %%
try:
    people.assign(
        body_mass_index = people["weight"] / (people["height"] / 100) ** 2,
        overweight = people["body_mass_index"] > 25
    )

except KeyError as e:
    print("Key error:", e)

# %%
d6 = people.assign(body_mass_index = people["weight"] / (people["height"] / 100) ** 2)
d6.assign(overweight = d6["body_mass_index"] > 25)
# Out:
#            hobby  height  weight  age  over 30  pets  body_mass_index  \
# alice     Biking     172      68   41     True   NaN        22.985398
# bob      Dancing     181      83   42     True   0.0        25.335002
# charles      NaN     185     112   34    False   5.0        32.724617
#
#          has_pets  overweight
# alice       False       False
# bob         False        True
# charles      True        True

# %%
try:
    (people
         .assign(body_mass_index = people["weight"] / (people["height"] / 100) ** 2)
         .assign(overweight = people["body_mass_index"] > 25)
    )
except KeyError as e:
    print("Key error:", e)

# %%
(people
    .assign(body_mass_index = lambda df: df["weight"] / (df["height"]/100) ** 2)
    .assign(overweight = lambda df: df["body_mass_index"] > 25)
)
# Out:
#            hobby  height  weight  age  over 30  pets  body_mass_index  \
# alice     Biking     172      68   41     True   NaN        22.985398
# bob      Dancing     181      83   42     True   0.0        25.335002
# charles      NaN     185     112   34    False   5.0        32.724617
#
#          has_pets  overweight
# alice       False       False
# bob         False        True
# charles      True        True

# %%
people.query("age > 30 and pets == 0")
# Out:
#        hobby  height  weight  age  over 30  pets  body_mass_index  has_pets
# bob  Dancing     181      83   42     True   0.0        25.335002     False

# %%
people.sort_index(ascending=False)
# Out:
#            hobby  height  weight  age  over 30  pets  body_mass_index  \
# charles      NaN     185     112   34    False   5.0        32.724617
# bob      Dancing     181      83   42     True   0.0        25.335002
# alice     Biking     172      68   41     True   NaN        22.985398
#
#          has_pets
# charles      True
# bob         False
# alice       False

# %%
people.sort_index(axis=1, inplace=True)
people
# Out:
#          age  body_mass_index  has_pets  height    hobby  over 30  pets  \
# alice     41        22.985398     False     172   Biking     True   NaN
# bob       42        25.335002     False     181  Dancing     True   0.0
# charles   34        32.724617      True     185      NaN    False   5.0
#
#          weight
# alice        68
# bob          83
# charles     112

# %%
people.sort_values(by="age", inplace=True)
people
# Out:
#          age  body_mass_index  has_pets  height    hobby  over 30  pets  \
# charles   34        32.724617      True     185      NaN    False   5.0
# alice     41        22.985398     False     172   Biking     True   NaN
# bob       42        25.335002     False     181  Dancing     True   0.0
#
#          weight
# charles     112
# alice        68
# bob          83

# %%
people.sort_values(by="body_mass_index", inplace=True)
people.plot(kind="line", x="body_mass_index", y=["height", "weight"])
plt.show()

# %%
people.plot(kind="scatter", x="height", y="weight", s=[4, 120, 200])
plt.show()

# %%
grades_array = np.array([[8,8,9],[10,9,9],[4,8,2],[9,10,10]])
grades = pd.DataFrame(grades_array, columns=['sep','oct','nov'], index=["alice","bob","charles","darwin"])
grades
# Out:
#          sep  oct  nov
# alice      8    8    9
# bob       10    9    9
# charles    4    8    2
# darwin     9   10   10

# %%
np.sqrt(grades)
# Out:
#               sep       oct       nov
# alice    2.828427  2.828427  3.000000
# bob      3.162278  3.000000  3.000000
# charles  2.000000  2.828427  1.414214
# darwin   3.000000  3.162278  3.162278

# %%
grades + 1
# Out:
#          sep  oct  nov
# alice      9    9   10
# bob       11   10   10
# charles    5    9    3
# darwin    10   11   11

# %%
grades >= 5
# Out:
#            sep   oct    nov
# alice     True  True   True
# bob       True  True   True
# charles  False  True  False
# darwin    True  True   True

# %%
grades.mean()
# Out:
# sep    7.75
# oct    8.75
# nov    7.50
# dtype: float64

# %%
(grades > 5).all()
# Out:
# sep    False
# oct     True
# nov    False
# dtype: bool

# %%
(grades > 5).all(axis = 1)
# Out:
# alice       True
# bob         True
# charles    False
# darwin      True
# dtype: bool

# %%
(grades == 10).any(axis=1)
# Out:
# alice      False
# bob         True
# charles    False
# darwin      True
# dtype: bool

# %%
grades - grades.mean()
# Out:
#           sep   oct  nov
# alice    0.25 -0.75  1.5
# bob      2.25  0.25  1.5
# charles -3.75 -0.75 -5.5
# darwin   1.25  1.25  2.5

# %%
pd.DataFrame([[7.75, 8.75, 7.50]]*4, index=grades.index, columns=grades.columns)
# Out:
#           sep   oct  nov
# alice    7.75  8.75  7.5
# bob      7.75  8.75  7.5
# charles  7.75  8.75  7.5
# darwin   7.75  8.75  7.5

# %%
grades - grades.values.mean()
# Out:
#          sep  oct  nov
# alice    0.0  0.0  1.0
# bob      2.0  1.0  1.0
# charles -4.0  0.0 -6.0
# darwin   1.0  2.0  2.0

# %%
bonus_array = np.array([[0, np.nan, 2], [np.nan, 1, 0], [0, 1, 0], [3, 3, 0]])
bonus_points = pd.DataFrame(bonus_array, columns=['oct', 'nov', 'dec'], index=['bob', 'colin', 'darwin', 'charles'])
bonus_points
# Out:
#          oct  nov  dec
# bob      0.0  NaN  2.0
# colin    NaN  1.0  0.0
# darwin   0.0  1.0  0.0
# charles  3.0  3.0  0.0

# %%
grades + bonus_points
# Out:
#          dec   nov   oct  sep
# alice    NaN   NaN   NaN  NaN
# bob      NaN   NaN   9.0  NaN
# charles  NaN   5.0  11.0  NaN
# colin    NaN   NaN   NaN  NaN
# darwin   NaN  11.0  10.0  NaN

# %%
(grades +bonus_points).fillna(0)
# Out:
#          dec   nov   oct  sep
# alice    0.0   0.0   0.0  0.0
# bob      0.0   0.0   9.0  0.0
# charles  0.0   5.0  11.0  0.0
# colin    0.0   0.0   0.0  0.0
# darwin   0.0  11.0  10.0  0.0

# %%
fixed_bonus_points = bonus_points.fillna(0)
fixed_bonus_points.insert(0, 'sep', 0)
fixed_bonus_points.loc['alice'] = 0
grades + fixed_bonus_points
# Out:
#          dec   nov   oct   sep
# alice    NaN   9.0   8.0   8.0
# bob      NaN   9.0   9.0  10.0
# charles  NaN   5.0  11.0   4.0
# colin    NaN   NaN   NaN   NaN
# darwin   NaN  11.0  10.0   9.0

# %%
bonus_points
# Out:
#          oct  nov  dec
# bob      0.0  NaN  2.0
# colin    NaN  1.0  0.0
# darwin   0.0  1.0  0.0
# charles  3.0  3.0  0.0

# %%
bonus_points.interpolate(axis=1)
# Out:
#          oct  nov  dec
# bob      0.0  1.0  2.0
# colin    NaN  1.0  0.0
# darwin   0.0  1.0  0.0
# charles  3.0  3.0  0.0

# %%
better_bonus_points = bonus_points.copy()
better_bonus_points.insert(0, 'sep', 0)
better_bonus_points.loc['alice'] = 0
better_bonus_points = better_bonus_points.interpolate(axis=1)
better_bonus_points
# Out:
#          sep  oct  nov  dec
# bob      0.0  0.0  1.0  2.0
# colin    0.0  0.5  1.0  0.0
# darwin   0.0  0.0  1.0  0.0
# charles  0.0  3.0  3.0  0.0
# alice    0.0  0.0  0.0  0.0

# %%
grades + better_bonus_points
# Out:
#          dec   nov   oct   sep
# alice    NaN   9.0   8.0   8.0
# bob      NaN  10.0   9.0  10.0
# charles  NaN   5.0  11.0   4.0
# colin    NaN   NaN   NaN   NaN
# darwin   NaN  11.0  10.0   9.0

# %%
grades['dec'] = np.nan
final_grades = grades + better_bonus_points
final_grades
# Out:
#           sep   oct   nov  dec
# alice     8.0   8.0   9.0  NaN
# bob      10.0   9.0  10.0  NaN
# charles   4.0  11.0   5.0  NaN
# colin     NaN   NaN   NaN  NaN
# darwin    9.0  10.0  11.0  NaN

# %%
final_grades_clear = final_grades.dropna(how='all')
final_grades_clear
# Out:
#           sep   oct   nov  dec
# alice     8.0   8.0   9.0  NaN
# bob      10.0   9.0  10.0  NaN
# charles   4.0  11.0   5.0  NaN
# darwin    9.0  10.0  11.0  NaN

# %%
final_grades_clear = final_grades_clear.dropna(axis=1, how='all')
final_grades_clear
# Out:
#           sep   oct   nov
# alice     8.0   8.0   9.0
# bob      10.0   9.0  10.0
# charles   4.0  11.0   5.0
# darwin    9.0  10.0  11.0

# %%
final_grades['hobby'] = ['Biking', 'Dancing', np.nan, 'Dancing', 'Biking']
final_grades
# Out:
#           sep   oct   nov  dec    hobby
# alice     8.0   8.0   9.0  NaN   Biking
# bob      10.0   9.0  10.0  NaN  Dancing
# charles   4.0  11.0   5.0  NaN      NaN
# colin     NaN   NaN   NaN  NaN  Dancing
# darwin    9.0  10.0  11.0  NaN   Biking

# %%
grouped_grades = final_grades.groupby('hobby')
grouped_grades

# %%
grouped_grades.mean()
# Out:
#           sep  oct   nov  dec
# hobby
# Biking    8.5  9.0  10.0  NaN
# Dancing  10.0  9.0  10.0  NaN

# %%
bonus_points
# Out:
#          oct  nov  dec
# bob      0.0  NaN  2.0
# colin    NaN  1.0  0.0
# darwin   0.0  1.0  0.0
# charles  3.0  3.0  0.0

# %%
more_grades = final_grades_clear.stack().reset_index()
more_grades.columns = ['name', 'month', 'grade']
more_grades['bonus'] = [np.nan, np.nan, np.nan, 0, np.nan, 2, 3, 3, 0, 0, 1, 0]
more_grades
# Out:
#        name month  grade  bonus
# 0     alice   sep    8.0    NaN
# 1     alice   oct    8.0    NaN
# 2     alice   nov    9.0    NaN
# 3       bob   sep   10.0    0.0
# 4       bob   oct    9.0    NaN
# 5       bob   nov   10.0    2.0
# 6   charles   sep    4.0    3.0
# 7   charles   oct   11.0    3.0
# 8   charles   nov    5.0    0.0
# 9    darwin   sep    9.0    0.0
# 10   darwin   oct   10.0    1.0
# 11   darwin   nov   11.0    0.0

# %%
pd.pivot_table(more_grades[['name', 'grade', 'bonus']], index='name')
# Out:
#             bonus      grade
# name
# alice         NaN   8.333333
# bob      1.000000   9.666667
# charles  2.000000   6.666667
# darwin   0.333333  10.000000

# %%
pd.pivot_table(more_grades, index='name', values=['grade', 'bonus'], aggfunc='max')
# Out:
#          bonus  grade
# name
# alice      NaN    9.0
# bob        2.0   10.0
# charles    3.0   11.0
# darwin     1.0   11.0

# %%
pd.pivot_table(more_grades, index='name', values='grade', columns='month', margins=True)
# Out:
# month      nov   oct    sep        All
# name
# alice     9.00   8.0   8.00   8.333333
# bob      10.00   9.0  10.00   9.666667
# charles   5.00  11.0   4.00   6.666667
# darwin   11.00  10.0   9.00  10.000000
# All       8.75   9.5   7.75   8.666667

# %%
pd.pivot_table(more_grades, index=['name', 'month'], margins=True)
# Out:
#                bonus  grade
# name    month
# alice   nov      NaN   9.00
#         oct      NaN   8.00
#         sep      NaN   8.00
# bob     nov    2.000  10.00
#         oct      NaN   9.00
#         sep    0.000  10.00
# charles nov    0.000   5.00
#         oct    3.000  11.00
#         sep    3.000   4.00
# darwin  nov    0.000  11.00
#         oct    1.000  10.00
#         sep    0.000   9.00
# All            1.125   8.75

# %%
much_data = np.fromfunction(lambda x, y: (x+y*y)%17*11, (10000, 26))
large_df = pd.DataFrame(much_data, columns=list("ABCDEFGHIJKLMNOPQRSTUVWXYZ"))
large_df[large_df % 16 == 0] = np.nan
large_df.insert(4, 'some_text', 'Blabla')
large_df
# Out:
#          A     B     C      D some_text      E      F     G      H      I  \
# 0      NaN  11.0  44.0   99.0    Blabla    NaN   88.0  22.0  165.0  143.0
# 1     11.0  22.0  55.0  110.0    Blabla    NaN   99.0  33.0    NaN  154.0
# 2     22.0  33.0  66.0  121.0    Blabla   11.0  110.0  44.0    NaN  165.0
# 3     33.0  44.0  77.0  132.0    Blabla   22.0  121.0  55.0   11.0    NaN
# 4     44.0  55.0  88.0  143.0    Blabla   33.0  132.0  66.0   22.0    NaN
# ...    ...   ...   ...    ...       ...    ...    ...   ...    ...    ...
# 9995   NaN   NaN  33.0   88.0    Blabla  165.0   77.0  11.0  154.0  132.0
# 9996   NaN  11.0  44.0   99.0    Blabla    NaN   88.0  22.0  165.0  143.0
# 9997  11.0  22.0  55.0  110.0    Blabla    NaN   99.0  33.0    NaN  154.0
# 9998  22.0  33.0  66.0  121.0    Blabla   11.0  110.0  44.0    NaN  165.0
# 9999  33.0  44.0  77.0  132.0    Blabla   22.0  121.0  55.0   11.0    NaN
#
#       ...     Q     R     S     T      U      V      W     X      Y      Z
# 0     ...  11.0   NaN  11.0  44.0   99.0    NaN   88.0  22.0  165.0  143.0
# 1     ...  22.0  11.0  22.0  55.0  110.0    NaN   99.0  33.0    NaN  154.0
# 2     ...  33.0  22.0  33.0  66.0  121.0   11.0  110.0  44.0    NaN  165.0
# 3     ...  44.0  33.0  44.0  77.0  132.0   22.0  121.0  55.0   11.0    NaN
# 4     ...  55.0  44.0  55.0  88.0  143.0   33.0  132.0  66.0   22.0    NaN
# ...   ...   ...   ...   ...   ...    ...    ...    ...   ...    ...    ...
# 9995  ...   NaN   NaN   NaN  33.0   88.0  165.0   77.0  11.0  154.0  132.0
# 9996  ...  11.0   NaN  11.0  44.0   99.0    NaN   88.0  22.0  165.0  143.0
# 9997  ...  22.0  11.0  22.0  55.0  110.0    NaN   99.0  33.0    NaN  154.0
# 9998  ...  33.0  22.0  33.0  66.0  121.0   11.0  110.0  44.0    NaN  165.0
# 9999  ...  44.0  33.0  44.0  77.0  132.0   22.0  121.0  55.0   11.0    NaN
#
# [10000 rows x 27 columns]

# %%
large_df.head()
# Out:
#       A     B     C      D some_text     E      F     G      H      I  ...  \
# 0   NaN  11.0  44.0   99.0    Blabla   NaN   88.0  22.0  165.0  143.0  ...
# 1  11.0  22.0  55.0  110.0    Blabla   NaN   99.0  33.0    NaN  154.0  ...
# 2  22.0  33.0  66.0  121.0    Blabla  11.0  110.0  44.0    NaN  165.0  ...
# 3  33.0  44.0  77.0  132.0    Blabla  22.0  121.0  55.0   11.0    NaN  ...
# 4  44.0  55.0  88.0  143.0    Blabla  33.0  132.0  66.0   22.0    NaN  ...
#
#       Q     R     S     T      U     V      W     X      Y      Z
# 0  11.0   NaN  11.0  44.0   99.0   NaN   88.0  22.0  165.0  143.0
# 1  22.0  11.0  22.0  55.0  110.0   NaN   99.0  33.0    NaN  154.0
# 2  33.0  22.0  33.0  66.0  121.0  11.0  110.0  44.0    NaN  165.0
# 3  44.0  33.0  44.0  77.0  132.0  22.0  121.0  55.0   11.0    NaN
# 4  55.0  44.0  55.0  88.0  143.0  33.0  132.0  66.0   22.0    NaN
#
# [5 rows x 27 columns]

# %%
large_df.tail(n=2)
# Out:
#          A     B     C      D some_text     E      F     G     H      I  ...  \
# 9998  22.0  33.0  66.0  121.0    Blabla  11.0  110.0  44.0   NaN  165.0  ...
# 9999  33.0  44.0  77.0  132.0    Blabla  22.0  121.0  55.0  11.0    NaN  ...
#
#          Q     R     S     T      U     V      W     X     Y      Z
# 9998  33.0  22.0  33.0  66.0  121.0  11.0  110.0  44.0   NaN  165.0
# 9999  44.0  33.0  44.0  77.0  132.0  22.0  121.0  55.0  11.0    NaN
#
# [2 rows x 27 columns]

# %%
large_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 27 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   A          8823 non-null   float64
#  1   B          8824 non-null   float64
#  2   C          8824 non-null   float64
#  3   D          8824 non-null   float64
#  4   some_text  10000 non-null  object
#  5   E          8822 non-null   float64
#  6   F          8824 non-null   float64
#  7   G          8824 non-null   float64
#  8   H          8822 non-null   float64
#  9   I          8823 non-null   float64
#  10  J          8823 non-null   float64
#  11  K          8822 non-null   float64
#  12  L          8824 non-null   float64
#  13  M          8824 non-null   float64
#  14  N          8822 non-null   float64
#  15  O          8824 non-null   float64
#  16  P          8824 non-null   float64
#  17  Q          8824 non-null   float64
#  18  R          8823 non-null   float64
#  19  S          8824 non-null   float64
#  20  T          8824 non-null   float64
#  21  U          8824 non-null   float64
#  22  V          8822 non-null   float64
#  23  W          8824 non-null   float64
#  24  X          8824 non-null   float64
#  25  Y          8822 non-null   float64
#  26  Z          8823 non-null   float64
# dtypes: float64(26), object(1)
# memory usage: 2.1+ MB

# %%
large_df.describe()
# Out:
#                  A            B            C            D            E  \
# count  8823.000000  8824.000000  8824.000000  8824.000000  8822.000000
# mean     87.977559    87.972575    87.987534    88.012466    87.983791
# std      47.535911    47.535523    47.521679    47.521679    47.535001
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
#                  F            G            H            I            J  ...  \
# count  8824.000000  8824.000000  8822.000000  8823.000000  8823.000000  ...
# mean     88.007480    87.977561    88.000000    88.022441    88.022441  ...
# std      47.519371    47.529755    47.536879    47.535911    47.535911  ...
# min      11.000000    11.000000    11.000000    11.000000    11.000000  ...
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000  ...
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000  ...
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000  ...
# max     165.000000   165.000000   165.000000   165.000000   165.000000  ...
#
#                  Q            R            S            T            U  \
# count  8824.000000  8823.000000  8824.000000  8824.000000  8824.000000
# mean     87.972575    87.977559    87.972575    87.987534    88.012466
# std      47.535523    47.535911    47.535523    47.521679    47.521679
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
#                  V            W            X            Y            Z
# count  8822.000000  8824.000000  8824.000000  8822.000000  8823.000000
# mean     87.983791    88.007480    87.977561    88.000000    88.022441
# std      47.535001    47.519371    47.529755    47.536879    47.535911
# min      11.000000    11.000000    11.000000    11.000000    11.000000
# 25%      44.000000    44.000000    44.000000    44.000000    44.000000
# 50%      88.000000    88.000000    88.000000    88.000000    88.000000
# 75%     132.000000   132.000000   132.000000   132.000000   132.000000
# max     165.000000   165.000000   165.000000   165.000000   165.000000
#
# [8 rows x 26 columns]

# %%
my_df = pd.DataFrame(
    [["Biking", 68.5, 1985, np.nan], ["Dancing", 83.1, 1984, 3]],
    columns=["hobby", "weight", "birthyear", "children"],
    index=["alice", "bob"]
)
my_df
# Out:
#          hobby  weight  birthyear  children
# alice   Biking    68.5       1985       NaN
# bob    Dancing    83.1       1984       3.0

# %%
my_df.to_csv("my_df.csv")
my_df.to_html("my_df.html")
my_df.to_json("my_df.json")

# %%
from pathlib import Path

for filename in ("my_df.csv", "my_df.html", "my_df.json"):
    print("#", filename)
    print(Path(filename).read_text())
    print()
# Out:
# # my_df.csv
# ,hobby,weight,birthyear,children
# alice,Biking,68.5,1985,
# bob,Dancing,83.1,1984,3.0
#
#
# # my_df.html
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>hobby</th>
#       <th>weight</th>
#       <th>birthyear</th>
#       <th>children</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>alice</th>
#       <td>Biking</td>
#       <td>68.5</td>
#       <td>1985</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>bob</th>
#       <td>Dancing</td>
#       <td>83.1</td>
#       <td>1984</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
#
# # my_df.json
# {"hobby":{"alice":"Biking","bob":"Dancing"},"weight":{"alice":68.5,"bob":83.1},"birthyear":{"alice":1985,"bob":1984},"children":{"alice":null,"bob":3.0}}

# %%
try: 
    my_df.to_excel("my_df.xlsx", sheet_name="People")
except ImportError as e:
    print(e)

# %%
my_df_loaded = pd.read_csv("my_df.csv", index_col=0)
my_df_loaded
# Out:
#          hobby  weight  birthyear  children
# alice   Biking    68.5       1985       NaN
# bob    Dancing    83.1       1984       3.0

# %%
us_cities = None

try:
    csv_url = "https://raw.githubusercontent.com/plotly/datasets/master/us-cities-top-1k.csv"
    us_cities = pd.read_csv(csv_url, index_col=0)
    us_cities = us_cities.head()
except IOError as e:
    print(e)

us_cities
# Out:
#                      State  Population        lat         lon
# City
# Marysville      Washington       63269  48.051764 -122.177082
# Perris          California       72326  33.782519 -117.228648
# Cleveland             Ohio      390113  41.499320  -81.694361
# Worcester    Massachusetts      182544  42.262593  -71.802293
# Columbia    South Carolina      133358  34.000710  -81.034814

# %%
city_loc = pd.DataFrame(
    [
        ["CA", "San Francisco", 37.781334, -122.416728],
        ["NY", "New York", 40.705649, -74.008344],
        ["FL", "Miami", 25.791100, -80.320733],
        ["OH", "Cleveland", 41.473508, -81.739791],
        ["UT", "Salt Lake City", 40.755851, -111.896657]
    ], columns=["state", "city", "lar", "lng"]
)

city_loc
# Out:
#   state            city        lar         lng
# 0    CA   San Francisco  37.781334 -122.416728
# 1    NY        New York  40.705649  -74.008344
# 2    FL           Miami  25.791100  -80.320733
# 3    OH       Cleveland  41.473508  -81.739791
# 4    UT  Salt Lake City  40.755851 -111.896657

# %%
city_pop = pd.DataFrame(
    [
        [808976, "San Francisco", "California"],
        [8363710, "New York", "New-York"],
        [413201, "Miami", "Florida"],
        [2242193, "Houston", "Texas"]
    ], index=[3,4,5,6], columns=["population", "city", "state"]
)

city_pop
# Out:
#    population           city       state
# 3      808976  San Francisco  California
# 4     8363710       New York    New-York
# 5      413201          Miami     Florida
# 6     2242193        Houston       Texas

# %%
pd.merge(left=city_loc, right=city_pop, on="city")
# Out:
#   state_x           city        lar         lng  population     state_y
# 0      CA  San Francisco  37.781334 -122.416728      808976  California
# 1      NY       New York  40.705649  -74.008344     8363710    New-York
# 2      FL          Miami  25.791100  -80.320733      413201     Florida

# %%
all_cities = pd.merge(left=city_loc, right=city_pop, on='city', how="outer")
all_cities
# Out:
#   state_x            city        lar         lng  population     state_y
# 0      OH       Cleveland  41.473508  -81.739791         NaN         NaN
# 1     NaN         Houston        NaN         NaN   2242193.0       Texas
# 2      FL           Miami  25.791100  -80.320733    413201.0     Florida
# 3      NY        New York  40.705649  -74.008344   8363710.0    New-York
# 4      UT  Salt Lake City  40.755851 -111.896657         NaN         NaN
# 5      CA   San Francisco  37.781334 -122.416728    808976.0  California

# %%
pd.merge(left=city_loc, right=city_pop, on="city", how="right")
# Out:
#   state_x           city        lar         lng  population     state_y
# 0      CA  San Francisco  37.781334 -122.416728      808976  California
# 1      NY       New York  40.705649  -74.008344     8363710    New-York
# 2      FL          Miami  25.791100  -80.320733      413201     Florida
# 3     NaN        Houston        NaN         NaN     2242193       Texas

# %%
city_pop2 = city_pop.copy()
city_pop2.columns = ["population", 'name', "state"]
pd.merge(left=city_loc, right=city_pop2, left_on="city", right_on="name")
# Out:
#   state_x           city        lar         lng  population           name  \
# 0      CA  San Francisco  37.781334 -122.416728      808976  San Francisco
# 1      NY       New York  40.705649  -74.008344     8363710       New York
# 2      FL          Miami  25.791100  -80.320733      413201          Miami
#
#       state_y
# 0  California
# 1    New-York
# 2     Florida

# %%
result_concat = pd.concat([city_loc, city_pop])
result_concat
# Out:
#         state            city        lar         lng  population
# 0          CA   San Francisco  37.781334 -122.416728         NaN
# 1          NY        New York  40.705649  -74.008344         NaN
# 2          FL           Miami  25.791100  -80.320733         NaN
# 3          OH       Cleveland  41.473508  -81.739791         NaN
# 4          UT  Salt Lake City  40.755851 -111.896657         NaN
# 3  California   San Francisco        NaN         NaN    808976.0
# 4    New-York        New York        NaN         NaN   8363710.0
# 5     Florida           Miami        NaN         NaN    413201.0
# 6       Texas         Houston        NaN         NaN   2242193.0

# %%
result_concat.loc[3]
# Out:
#         state           city        lar        lng  population
# 3          OH      Cleveland  41.473508 -81.739791         NaN
# 3  California  San Francisco        NaN        NaN    808976.0

# %%
pd.concat([city_loc, city_pop], ignore_index=True)
# Out:
#         state            city        lar         lng  population
# 0          CA   San Francisco  37.781334 -122.416728         NaN
# 1          NY        New York  40.705649  -74.008344         NaN
# 2          FL           Miami  25.791100  -80.320733         NaN
# 3          OH       Cleveland  41.473508  -81.739791         NaN
# 4          UT  Salt Lake City  40.755851 -111.896657         NaN
# 5  California   San Francisco        NaN         NaN    808976.0
# 6    New-York        New York        NaN         NaN   8363710.0
# 7     Florida           Miami        NaN         NaN    413201.0
# 8       Texas         Houston        NaN         NaN   2242193.0

# %%
pd.concat([city_loc, city_pop], join="inner")
# Out:
#         state            city
# 0          CA   San Francisco
# 1          NY        New York
# 2          FL           Miami
# 3          OH       Cleveland
# 4          UT  Salt Lake City
# 3  California   San Francisco
# 4    New-York        New York
# 5     Florida           Miami
# 6       Texas         Houston

# %%
pd.concat([city_loc, city_pop], axis=1)
# Out:
#   state            city        lar         lng  population           city  \
# 0    CA   San Francisco  37.781334 -122.416728         NaN            NaN
# 1    NY        New York  40.705649  -74.008344         NaN            NaN
# 2    FL           Miami  25.791100  -80.320733         NaN            NaN
# 3    OH       Cleveland  41.473508  -81.739791    808976.0  San Francisco
# 4    UT  Salt Lake City  40.755851 -111.896657   8363710.0       New York
# 5   NaN             NaN        NaN         NaN    413201.0          Miami
# 6   NaN             NaN        NaN         NaN   2242193.0        Houston
#
#         state
# 0         NaN
# 1         NaN
# 2         NaN
# 3  California
# 4    New-York
# 5     Florida
# 6       Texas

# %%
pd.concat([city_loc.set_index("city"), city_pop.set_index("city")], axis=1)
# Out:
#                state        lar         lng  population       state
# city
# San Francisco     CA  37.781334 -122.416728    808976.0  California
# New York          NY  40.705649  -74.008344   8363710.0    New-York
# Miami             FL  25.791100  -80.320733    413201.0     Florida
# Cleveland         OH  41.473508  -81.739791         NaN         NaN
# Salt Lake City    UT  40.755851 -111.896657         NaN         NaN
# Houston          NaN        NaN         NaN   2242193.0       Texas

# %%
city_eco = city_pop.copy()
city_eco["eco_code"] = [17, 17, 34, 20]
city_eco
# Out:
#    population           city       state  eco_code
# 3      808976  San Francisco  California        17
# 4     8363710       New York    New-York        17
# 5      413201          Miami     Florida        34
# 6     2242193        Houston       Texas        20

# %%
city_eco["economy"] = pd.Categorical(
    city_eco["eco_code"].map({17: "Banking", 20:"Energy", 34:"Tourism"})
)
city_eco
# Out:
#    population           city       state  eco_code  economy
# 3      808976  San Francisco  California        17  Banking
# 4     8363710       New York    New-York        17  Banking
# 5      413201          Miami     Florida        34  Tourism
# 6     2242193        Houston       Texas        20   Energy

# %%
city_eco["economy"].cat.categories
# Out:
# Index(['Banking', 'Energy', 'Tourism'], dtype='object')

# %%
city_eco["economy"] = city_eco["economy"].cat.rename_categories({"Banking":"Finance"})
city_eco
# Out:
#    population           city       state  eco_code  economy
# 3      808976  San Francisco  California        17  Finance
# 4     8363710       New York    New-York        17  Finance
# 5      413201          Miami     Florida        34  Tourism
# 6     2242193        Houston       Texas        20   Energy
